# %%
import pandas as pd
import numpy as np

NCA51019_scan1run1 = 'https://s3-us-west-1.amazonaws.com/dianaciuca.com/Egert/NCA51019/scan1/run1.tsv'
NCA51019_scan1run2 = 'https://s3-us-west-1.amazonaws.com/dianaciuca.com/Egert/NCA51019/scan1/run2.tsv'
NCA51019_scan1run3 = 'https://s3-us-west-1.amazonaws.com/dianaciuca.com/Egert/NCA51019/scan1/run3.tsv'

NCA51019_s1r1 = pd.read_csv(NCA51019_scan1run1, sep='\t', header=0)
NCA51019_s1r2 = pd.read_csv(NCA51019_scan1run2, sep='\t', header=0)
NCA51019_s1r3 = pd.read_csv(NCA51019_scan1run3, sep='\t', header=0)

NCA51019_s1r1r2r3 = pd.concat([NCA51019_s1r1, NCA51019_s1r2, NCA51019_s1r3], keys=['s1r1', 's1r2', 's1r3'])

NCA51019_scan2run1 = 'https://s3-us-west-1.amazonaws.com/dianaciuca.com/Egert/NCA51019/scan2/run1.tsv'
NCA51019_scan2run2 = 'https://s3-us-west-1.amazonaws.com/dianaciuca.com/Egert/NCA51019/scan2/run2.tsv'
NCA51019_scan2run3 = 'https://s3-us-west-1.amazonaws.com/dianaciuca.com/Egert/NCA51019/scan2/run3.tsv'

NCA51019_s2r1 = pd.read_csv(NCA51019_scan2run1, sep='\t', header=0)
NCA51019_s2r2 = pd.read_csv(NCA51019_scan2run2, sep='\t', header=0)
NCA51019_s2r3 = pd.read_csv(NCA51019_scan2run3, sep='\t', header=0)

NCA51019_s2r1r2r3 = pd.concat([NCA51019_s2r1, NCA51019_s2r2, NCA51019_s2r3], keys=['s2r1', 's2r2', 's2r3'])


NCA51019_scan3run1 = 'https://s3-us-west-1.amazonaws.com/dianaciuca.com/Egert/NCA51019/scan3/run1.tsv'
NCA51019_scan3run2 = 'https://s3-us-west-1.amazonaws.com/dianaciuca.com/Egert/NCA51019/scan3/run2.tsv'
NCA51019_scan3run3 = 'https://s3-us-west-1.amazonaws.com/dianaciuca.com/Egert/NCA51019/scan3/run3.tsv'

NCA51019_s3r1 = pd.read_csv(NCA51019_scan3run1, sep='\t', header=0)
NCA51019_s3r2 = pd.read_csv(NCA51019_scan3run2, sep='\t', header=0)
NCA51019_s3r3 = pd.read_csv(NCA51019_scan3run3, sep='\t', header=0)

NCA51019_s3r1r2r3 = pd.concat([NCA51019_s3r1, NCA51019_s3r2, NCA51019_s3r3], keys=['s3r1', 's3r2', 's3r3'])


NCA51019_scan3run1 = 'https://s3-us-west-1.amazonaws.com/dianaciuca.com/Egert/NCA51019/scan3/run1.tsv'
NCA51019_scan3run2 = 'https://s3-us-west-1.amazonaws.com/dianaciuca.com/Egert/NCA51019/scan3/run2.tsv'
NCA51019_scan3run3 = 'https://s3-us-west-1.amazonaws.com/dianaciuca.com/Egert/NCA51019/scan3/run3.tsv'

NCA51019_s3r1 = pd.read_csv(NCA51019_scan3run1, sep='\t', header=0)
NCA51019_s3r2 = pd.read_csv(NCA51019_scan3run2, sep='\t', header=0)
NCA51019_s3r3 = pd.read_csv(NCA51019_scan3run3, sep='\t', header=0)

NCA51019_s3r1r2r3 = pd.concat([NCA51019_s3r1, NCA51019_s3r2, NCA51019_s3r3], keys=['s3r1', 's3r2', 's3r3'])

# %%
NCA51019_s1r1r2r3
# Out:
#              onset  duration ImageCategory ImageSubcategory ViewingCondition  \
# s1r1 0   10.028507        30      negative          general      reappraisal
#      1   55.305502        30      negative            dying      reappraisal
#      2  100.535658        30      negative            dying          passive
#      3  145.748958        30       neutral              NaN          passive
#      4  190.995668        30      negative          general          passive
#      5  236.208194        30      negative          general          passive
#      6  281.421666        30       neutral              NaN          passive
#      7  326.635102        30      negative            dying      reappraisal
#      8  371.865069        30      negative          general      reappraisal
#      9  417.078619        30      negative            dying          passive
# s1r2 0   10.020274        30      negative          general      reappraisal
# ...

# %%
NCA51019_s2r1r2r3
# Out:
#              onset  duration ImageCategory ImageSubcategory ViewingCondition  \
# s2r1 0   10.033870        30      negative          general      reappraisal
#      1   55.329779        30      negative            dying      reappraisal
#      2  100.559899        30      negative            dying          passive
#      3  145.773462        30       neutral              NaN          passive
#      4  191.053566        30      negative          general          passive
#      5  236.265759        30      negative          general          passive
#      6  281.495891        30       neutral              NaN          passive
#      7  326.725973        30      negative            dying      reappraisal
#      8  371.939463        30      negative          general      reappraisal
#      9  417.152973        30      negative            dying          passive
# s2r2 0   10.021023        30      negative            dying      reappraisal
# ...

# %%
NCA51019_all = pd.concat([NCA51019_s1r1r2r3, NCA51019_s2r1r2r3, NCA51019_s3r1r2r3], keys=['scan 1', 'scan 2', 'scan 3'])

# %%
NCA51019_all
# Out:
#                     onset  duration ImageCategory ImageSubcategory  \
# scan 1 s1r1 0   10.028507        30      negative          general
#             1   55.305502        30      negative            dying
#             2  100.535658        30      negative            dying
#             3  145.748958        30       neutral              NaN
#             4  190.995668        30      negative          general
#             5  236.208194        30      negative          general
#             6  281.421666        30       neutral              NaN
#             7  326.635102        30      negative            dying
#             8  371.865069        30      negative          general
#             9  417.078619        30      negative            dying
#        s1r2 0   10.020274        30      negative          general
#             1   55.267024        30      negative          general
#             2  100.480463        30      negative            dying
# ...

# %%
NCA51019_re = NCA51019_all[(NCA51019_all['ViewingCondition'] == 'reappraisal') & (NCA51019_all['ImageCategory'] == 'negative')]

# %%
NCA51019_re
# Out:
#                     onset  duration ImageCategory ImageSubcategory  \
# scan 1 s1r1 0   10.028507        30      negative          general
#             1   55.305502        30      negative            dying
#             7  326.635102        30      negative            dying
#             8  371.865069        30      negative          general
#        s1r2 0   10.020274        30      negative          general
#             2  100.480463        30      negative            dying
#             5  236.120786        30      negative          general
#             9  417.074498        30      negative            dying
#        s1r3 3  145.735349        30      negative          general
#             4  190.948622        30      negative            dying
#             6  281.408722        30      negative          general
#             8  371.835745        30      negative            dying
# scan 2 s2r1 0   10.033870        30      negative          general
# ...
